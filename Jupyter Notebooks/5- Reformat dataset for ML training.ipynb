# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import libraries
import numpy as np
import pandas as pd
import csv

# set display options
#pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# import datasets
detected_peptides = pd.read_table('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/detected_peptides_NSAF.tsv')
undetected_peptides = pd.read_table('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/undetected_peptides_NSAF.tsv')

# %%
detected_peptides.head()
# Out:
#   Protein                 Peptide       PEP  Protein_length  PSM_per_protein  \
# 0  P98179         YYDSRPGGYGYGYGR  0.004787           157.0                7
# 1  P30084           NNTVGLIQLNRPK  0.004787           290.0               29
# 2  P62851             DKLNNLVLFDK  0.004787             NaN               10
# 3  P82673           NMEINKEELLGTK  0.004787           323.0                7
# 4  Q14566  NLYHNLCTSLFPTIHGNDEVKR  0.004787           821.0               42
#
#    Quantification
# 0        0.044586
# 1        0.100000
# 2             NaN
# 3        0.021672
# 4        0.051157

# %%
undetected_peptides.head()
# Out:
#   Protein                   Peptide  Cleavage  Prediction  Probability  \
# 0  P18031                   EFEQIDK         1           1        0.500
# 1  Q96P70                  AIITDSVK         1           1        0.500
# 2  P33176          SAEIDSDDTGGSAAQK         1           1        0.500
# 3  Q15393  ELAAEMAAAFLNENLPESIFGAPK         1           1        0.501
# 4  Q96P70     AAAAAAGAASGLPGPVAQGLK         1           1        0.501
#
#    Length  Quantification
# 0     435        0.022989
# 1    1041        0.025937
# 2     963        0.045691
# 3    1217        0.002465
# 4    1041        0.025937

# %%
# take the mean of the entire PEP column in detected peptides, and apply it to all rows in undetected peptides
undetected_peptides["PEP"] = [detected_peptides["PEP"].mean()]*undetected_peptides.shape[0]
undetected_peptides
# Out:
#      Protein                   Peptide  Cleavage  Prediction  Probability  \
# 0     P18031                   EFEQIDK         1           1        0.500
# 1     Q96P70                  AIITDSVK         1           1        0.500
# 2     P33176          SAEIDSDDTGGSAAQK         1           1        0.500
# 3     Q15393  ELAAEMAAAFLNENLPESIFGAPK         1           1        0.501
# 4     Q96P70     AAAAAAGAASGLPGPVAQGLK         1           1        0.501
# ...      ...                       ...       ...         ...          ...
# 6047  P07814                   YYTLFGR         0           1        0.910
# 6048  P06576           VALVYGQMNEPPGAR         0           1        0.910
# 6049  Q6P2Q9              ADWWTNTAHYNR         0           1        0.910
# 6050  O43707               GISQEQMQEFR         0           1        0.910
# 6051  P17174                 HIYLLPSGR         0           1        0.910
#
#       Length  Quantification       PEP
# 0        435        0.022989  0.011226
# ...

# %%
# drop "PSM_per_protein"
detected_peptides = detected_peptides.drop(labels=['PSM_per_protein'], axis=1)
detected_peptides.head()
# Out:
#   Protein                 Peptide       PEP  Protein_length  Quantification
# 0  P98179         YYDSRPGGYGYGYGR  0.004787           157.0        0.044586
# 1  P30084           NNTVGLIQLNRPK  0.004787           290.0        0.100000
# 2  P62851             DKLNNLVLFDK  0.004787             NaN             NaN
# 3  P82673           NMEINKEELLGTK  0.004787           323.0        0.021672
# 4  Q14566  NLYHNLCTSLFPTIHGNDEVKR  0.004787           821.0        0.051157

# %%
# make all column names the same for both datasets
undetected_peptides = undetected_peptides.rename(columns={"Length": "Protein_length"})
undetected_peptides.head()
# Out:
#   Protein                   Peptide  Cleavage  Prediction  Probability  \
# 0  P18031                   EFEQIDK         1           1        0.500
# 1  Q96P70                  AIITDSVK         1           1        0.500
# 2  P33176          SAEIDSDDTGGSAAQK         1           1        0.500
# 3  Q15393  ELAAEMAAAFLNENLPESIFGAPK         1           1        0.501
# 4  Q96P70     AAAAAAGAASGLPGPVAQGLK         1           1        0.501
#
#    Protein_length  Quantification       PEP
# 0             435        0.022989  0.011226
# 1            1041        0.025937  0.011226
# 2             963        0.045691  0.011226
# 3            1217        0.002465  0.011226
# 4            1041        0.025937  0.011226

# %%
detected_peptides.head()
# Out:
#   Protein                 Peptide       PEP  Protein_length  Quantification
# 0  P98179         YYDSRPGGYGYGYGR  0.004787           157.0        0.044586
# 1  P30084           NNTVGLIQLNRPK  0.004787           290.0        0.100000
# 2  P62851             DKLNNLVLFDK  0.004787             NaN             NaN
# 3  P82673           NMEINKEELLGTK  0.004787           323.0        0.021672
# 4  Q14566  NLYHNLCTSLFPTIHGNDEVKR  0.004787           821.0        0.051157

# %%
# make column order identical for both datasets
undetected_peptides = undetected_peptides[['Protein', 'Peptide', 'PEP', 'Protein_length', 'Quantification']]
undetected_peptides.head()
# Out:
#   Protein                   Peptide       PEP  Protein_length  Quantification
# 0  P18031                   EFEQIDK  0.011226             435        0.022989
# 1  Q96P70                  AIITDSVK  0.011226            1041        0.025937
# 2  P33176          SAEIDSDDTGGSAAQK  0.011226             963        0.045691
# 3  Q15393  ELAAEMAAAFLNENLPESIFGAPK  0.011226            1217        0.002465
# 4  Q96P70     AAAAAAGAASGLPGPVAQGLK  0.011226            1041        0.025937

# %%
# export datasets as TSV
detected_peptides.to_csv("/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/detected_peptides_all.tsv", sep='\t', index=False)
undetected_peptides.to_csv("/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/undetected_peptides_all.tsv", sep='\t', index=False)

# %%
print(detected_peptides.shape)
print(undetected_peptides.shape)
# Out:
# (1917, 5)
# (6052, 5)

# %%
# !python("/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1")
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `"/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1"'
# /bin/bash: -c: line 1: `python("/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1")'

# %%
### convert the aaindex1 text file into a df file
import numpy as np
import pandas as pd


def convert_aaindex1_to_df(data, output_file_name):
    """
    Converts raw AAIndex1 into Pandas DataFrame. Outputs amino acid indices with accession
    and description. Adapted from: https://github.com/tadorfer/AAIndex/blob/master/raw_to_df.py.
    Note: AAIndex1 data was downloaded from: https://www.genome.jp/ftp/db/community/aaindex/.
    """

    # define column names and initialize dataframe
    columns = ['Accession', 'Description']
    aa = ['A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I',
          'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
    columns = columns + aa
    df = pd.DataFrame(data=[], columns=columns)

    # conversion by parsing text file line by line
    with open(data) as f:
        for i, line in enumerate(f):
            if line[0] == 'H':
                accession = line.split()[1]
            if line[0] == 'D':
                description = line.split()[1:]
                description = ' '.join(description)
            if line[0] == 'I':
                tmp = i
            if 'tmp' in locals():
                if i == tmp + 1:
                    tmp1 = [accession] + [description] + line.split()
                if i == tmp + 2:
                    tmp2 = line.split()
                    tmp_all = tmp1 + tmp2
                    tmp_all = pd.DataFrame([tmp_all], columns=columns)
                    df = df.append([tmp_all]).reset_index(drop=True)
                    df.to_csv(output_file_name, sep='\t', index=False)

    return df

print (convert_aaindex1_to_df("/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1", "/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1_df"))

# %%
### calculate or map the the output aaindex1_df to the detected dataset
def calculate_aaindex1_features(peptide_df_file, aaindex1_df_file, output_file_name):

    peptide_df = pd.read_table(peptide_df_file)
    aaindex1_df = pd.read_table(aaindex1_df_file)

    # turn aaindex1 values into dict format so peptide AAs can be mapped to dictionary values
    print('Turning AAIndex1 values into dict format')
    del aaindex1_df['Description']
    aaindex1_df = aaindex1_df.set_index('Accession')
    aaindex1_dict = aaindex1_df.to_dict(orient='records')
    aaindex1_df.insert(loc=0, column='aa_dict', value=aaindex1_dict)

    # add aaindex1 accession columns to peptide_df
    print('Adding AAIndex1 accession columns to peptide_df')
    aaindex1_df = aaindex1_df.reset_index(level=0)
    aaindex1_accession_cols = []
    for row in aaindex1_df['Accession']:
        aaindex1_accession_cols.append(row)
    peptide_df = pd.concat([peptide_df, pd.DataFrame(columns=aaindex1_accession_cols)])

    # calculate aaindex1 values for each peptide
    print('Calculating AAIndex1 values for each peptide')
    all_peptide_vals = []

    for peptide in peptide_df['Peptide']:
        peptide_vals = []
        for aa_dict in aaindex1_df['aa_dict']:
            aaindex1_vals = sum([aa_dict[x] for x in peptide]) / len(peptide) # divide by peptide length for further normalisation
            peptide_vals.append(aaindex1_vals)
        all_peptide_vals.append(peptide_vals)

    print('Almost done, just creating the df')
    peptide_df.iloc[0:, 5:] = all_peptide_vals  # column index to add aaindex1 values will vary by df, need to specify
    peptide_df.to_csv(output_file_name, sep='\t', index=False)

    print('Finished!')
calculate_aaindex1_features('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/detected_peptides_all.tsv','/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1_df', '/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/detected_peptides_all_aaindex1.tsv')
# Out:
# Turning AAIndex1 values into dict format
# Adding AAIndex1 accession columns to peptide_df
# Calculating AAIndex1 values for each peptide
# Almost done, just creating the df
# Finished!

# %%
### calculate or map the the output aaindex1_df to the undetected dataset
def calculate_aaindex1_features(peptide_df_file, aaindex1_df_file, output_file_name):

    peptide_df = pd.read_table(peptide_df_file)
    aaindex1_df = pd.read_table(aaindex1_df_file)

    # turn aaindex1 values into dict format so peptide AAs can be mapped to dictionary values
    print('Turning AAIndex1 values into dict format')
    del aaindex1_df['Description']
    aaindex1_df = aaindex1_df.set_index('Accession')
    aaindex1_dict = aaindex1_df.to_dict(orient='records')
    aaindex1_df.insert(loc=0, column='aa_dict', value=aaindex1_dict)

    # add aaindex1 accession columns to peptide_df
    print('Adding AAIndex1 accession columns to peptide_df')
    aaindex1_df = aaindex1_df.reset_index(level=0)
    aaindex1_accession_cols = []
    for row in aaindex1_df['Accession']:
        aaindex1_accession_cols.append(row)
    peptide_df = pd.concat([peptide_df, pd.DataFrame(columns=aaindex1_accession_cols)])

    # calculate aaindex1 values for each peptide
    print('Calculating AAIndex1 values for each peptide')
    all_peptide_vals = []

    for peptide in peptide_df['Peptide']:
        peptide_vals = []
        for aa_dict in aaindex1_df['aa_dict']:
            aaindex1_vals = sum([aa_dict[x] for x in peptide]) / len(peptide) # divide by peptide length for further normalisation
            peptide_vals.append(aaindex1_vals)
        all_peptide_vals.append(peptide_vals)

    print('Almost done, just creating the df')
    peptide_df.iloc[0:, 5:] = all_peptide_vals  # column index to add aaindex1 values will vary by df, need to specify
    peptide_df.to_csv(output_file_name, sep='\t', index=False)

    print('Finished!')
calculate_aaindex1_features('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/undetected_peptides_all.tsv','/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1_df', '/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/undetected_peptides_all_aaindex1.tsv')
# Out:
# Turning AAIndex1 values into dict format
# Adding AAIndex1 accession columns to peptide_df
# Calculating AAIndex1 values for each peptide
# Almost done, just creating the df
# Finished!

# %%
# load AAIndex1 datasets
aaindex1_df = pd.read_table('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/aaindex1_df')
detected_peptides_all = pd.read_table('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/detected_peptides_all_aaindex1.tsv')
undetected_peptides_all = pd.read_table('/content/drive/MyDrive/Colab Notebooks/peptide ml detection/data/undetected_peptides_all_aaindex1.tsv')

# %%
print(aaindex1_df.shape)
print(detected_peptides_all.shape)
print(undetected_peptides_all.shape)
# Out:
# (566, 22)
# (1917, 571)
# (6052, 571)

# %%
undetected_peptides_all.head()
# Out:
#   Protein                   Peptide       PEP  Protein_length  Quantification  \
# 0  P18031                   EFEQIDK  0.011226           435.0        0.022989
# 1  Q96P70                  AIITDSVK  0.011226          1041.0        0.025937
# 2  P33176          SAEIDSDDTGGSAAQK  0.011226           963.0        0.045691
# 3  Q15393  ELAAEMAAAFLNENLPESIFGAPK  0.011226          1217.0        0.002465
# 4  Q96P70     AAAAAAGAASGLPGPVAQGLK  0.011226          1041.0        0.025937
#
#    ANDN920101  ARGP820101  ARGP820102  ARGP820103  BEGF750101  ...  \
# 0    4.382857    0.970000    0.637143    0.708571    0.610000  ...
# 1    4.271250    1.010000    0.885000    1.006250    0.638750  ...
# 2    4.380625    0.461875    0.672500    0.765000    0.563125  ...
# 3    4.365417    0.952500    1.197917    1.308333    0.707083  ...
# 4    4.258571    0.726190    1.113810    1.262381    0.701429  ...
#
#    KARS160113  KARS160114  KARS160115  KARS160116  KARS160117  KARS160118  \
# ...
